# %%
CATALOG_NAME="Payment_monitoring"
SCHEMA="fintech"

LANDING_VOLUME_PATH=f"/Volumes/{CATALOG_NAME}/{SCHEMA}/raw_data"
CHECKPOINT_PATH=f"/Volumes/{CATALOG_NAME}/{SCHEMA}/checkpoints"

TRANSACTIONS_RAW_PATH=f"{LANDING_VOLUME_PATH}/transactions"
CUSTOMERS_RAW_PATH=f"{LANDING_VOLUME_PATH}/customers"
MERCHANTS_RAW_PATH=f"{LANDING_VOLUME_PATH}/merchants"

#Table names
TABLE_BRONZE_TRANSACTIONS=f"{CATALOG_NAME}/{SCHEMA}.transactions_bronze"
TABLE_SILVER_TRANSACTIONS=f"{CATALOG_NAME}/{SCHEMA}.transactions_silver"
TABLE_SILVER_ALERTS=f"{CATALOG_NAME}/{SCHEMA}.fraud_alerts_silver"
TABLE_GOLD_DAILY_SUMMARY=f"{CATALOG_NAME}/{SCHEMA}.daily_merchant_summary_gold"
TABLE_GOLD_SAR_PREFILL=f"{CATALOG_NAME}/{SCHEMA}.sqr_prefill_dataset_gold"

# Dimension Tables (Silver)
TABLE_SILVER_CUSTOMERS = f"{CATALOG_NAME}.{SCHEMA}.customers_silver"
TABLE_SILVER_MERCHANTS = f"{CATALOG_NAME}.{SCHEMA}.merchants_silver"

# Data Generation Settings
TOTAL_TXNS = 50000
BATCH_SIZE = 1000
NUM_BATCHES = 5
DUPLICATE_RATE = 0.02
NULL_MERCHANT_RATE = 0.01

print(f"✅ Variables loaded for catalog: {CATALOG_NAME}")
